# %% [markdown]
# <a href="https://colab.research.google.com/github/prachu12/scraping/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bs4
# !pip install requests
# !conda install requests
# !pip install simplejson
# Out:
# ...
# /bin/bash: conda: command not found
# ...
#      |████████████████████████████████| 130 kB 5.2 MB/s
# ...

# %%
from bs4 import BeautifulSoup as bs
import requests

r = requests.get("https://github.com/meetDeveloper/freeDictionaryAPI")
soup = bs(r.content)
contents = soup.prettify()
print(contents)
# Out:
# <!DOCTYPE html>
# <html data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
#   <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-13dc275a3a314268790358e25956033c.css" integrity="sha512-E9wnWjoxQmh5A1jiWVYDPKOvA8VPf0iKQYoc+9ycMJvtAi9gOSlaUci+W2smxFIlWkV8hkX+O27S8NIB59iIDw==" media="all" rel="stylesheet"/>
# ...

# %%
import requests
response = requests.get("https://github.com/meetDeveloper/freeDictionaryAPI")
print(response.status_code)
# Out:
# 200

# %%
import requests
response = requests.get("https://api.dictionaryapi.dev/api/v2/entries/en/")

response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-18-eefc31d21382> in <module>()
#       3 response = requests.get("https://api.dictionaryapi.dev/api/v2/entries/en/")
#       4
# ----> 5 response.json()
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /usr/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
# ...

# %%
title = soup.title()
title[:1]
# Out:
# []

# %%
paras = soup.find_all('p')
print(paras)
# Out:
# [<p class="f4 mb-3">
#         There was no free Dictionary API on the web when I wanted one for my friend, so I created one.
# ...

# %%
anchors = soup.find_all('a')
print(anchors)
# Out:
# [<a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>, <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# ...

# %%
 print(soup.find('p').get_text())
print(soup.get_text())
# Out:
#         There was no free Dictionary API on the web when I wanted one for my friend, so I created one.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# GitHub - meetDeveloper/freeDictionaryAPI: There was no free Dictionary API on the web when I wanted one for my friend, so I created one.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Sign up
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Why GitHub?
#
#
#
#
#
#
#       Features
#
#
#
#       Mobile
#
#
#
#       Actions
#
#
#
#       Codespaces
#
#
#
#       Packages
#
#
#
#       Security
#
#
#
#       Code review
#
#
#
#       Issues
#
#
#
#       Integrations
#
#
#
#       GitHub Sponsors
#
#
#
#       Customer stories
#
#
#
#
#
#
# Team
#
#
# Enterprise
#
#
#
#
#         Explore
#
#
#
#
#
#
# ...

# %%
anchors = soup.find_all('a')
all_links = set()

for link in anchors:
    if(link.get('href')!='#'):
        linkText = "https://github.com/meetDeveloper/freeDictionaryAPI" + link.get('href')
        all_links.add(link)
        print(linkText)
# Out:
# https://github.com/meetDeveloper/freeDictionaryAPI#start-of-content
# https://github.com/meetDeveloper/freeDictionaryAPIhttps://github.com/
# https://github.com/meetDeveloper/freeDictionaryAPI/signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2F%3Cuser-name%3E%2F%3Crepo-name%3E&source=header-repo
# https://github.com/meetDeveloper/freeDictionaryAPI/features
# https://github.com/meetDeveloper/freeDictionaryAPI/mobile
# https://github.com/meetDeveloper/freeDictionaryAPI/features/actions
# https://github.com/meetDeveloper/freeDictionaryAPI/features/codespaces
# https://github.com/meetDeveloper/freeDictionaryAPI/features/packages
# https://github.com/meetDeveloper/freeDictionaryAPI/features/security
# https://github.com/meetDeveloper/freeDictionaryAPI/features/code-review
# https://github.com/meetDeveloper/freeDictionaryAPI/features/issues
# https://github.com/meetDeveloper/freeDictionaryAPI/features/integrations
# https://github.com/meetDeveloper/freeDictionaryAPI/sponsors
# ...

# %%
navbarSupportContent = soup.find(id = 'responsive-meta-container')
print(navbarSupportContent.children)

# %%
elem = soup.select('#loginModel')
print(elem)
# Out:
# []

# %%
def get_topic_descs(doc):
    desc_selector = 'f5 color-text-secondary mb-0 mt-1'
    topic_desc_tags = doc.find_all('p', {'class': "f4 mb-3"})
    topic_descs = []
    for tag in topic_desc_tags:
        topic_descs.append(tag.text.strip())
    return topic_descs

# %%
heading = soup.find(class:""h4 mb-3")
heading
# Out:
#   File "<ipython-input-28-203b65ae5adc>", line 1
#     heading = soup.find(class:""h4 mb-3")
#                             ^
# SyntaxError: invalid syntax

# %%
def get_content_value(row_data):
#     if row_data.find("ul")
#        return [li.get_text() for li in row_data.find_all("ul")]
#     else:
#         return row_data.get_text()       

# web_info = {}
for index, row in enumerate(rows):
    if index == 0:
        web_info['title'] = row.find("th").get_text()
    elif index == 1:
        continue
    else:
        content_key = row.find("th").get_text()
        content_value = get_content_value(row.find("td"))
        web_info[content_key] = content_value

web_info
# Out:
#   File "<ipython-input-32-6421aca25e8b>", line 8
#     for index, row in enumerate(rows):
#       ^
# IndentationError: expected an indented block
